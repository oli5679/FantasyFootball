# %% [markdown]
# # Fixture Modelling

# %% [markdown]
# How many goals are PL teams to score and concede in upcoming fixtures?

# %% [markdown]
# See here for some more technical details http://web.math.ku.dk/~rolf/teaching/thesis/DixonColes.pdf

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from datetime import timezone
import numpy as np
from collections import defaultdict
import scipy.stats
import scipy.optimize
import seaborn as sns

# %%
# !cd ../data/Fantasy-Premier-League && git pull # pull latest data
# Out:
# Already up to date.

# %% [markdown]
# ## Load data

# %%
SEASONS = ['2018-19' ,'2019-20','2020-21', '2021-22',]

# %%
combined = pd.DataFrame()
for season in SEASONS:
    df = pd.read_csv(f'../data/Fantasy-Premier-League/data/{season}/fixtures.csv',parse_dates=['kickoff_time'])
    df['season'] = season
    combined = df.append(combined)

# %%
teams = pd.read_csv(f'../data/Fantasy-Premier-League/data/master_team_list.csv')

# %% [markdown]
# the numbers aren't consistent across seasons so we merge on names and come up with our own numbering

# %%
def clean_names(combined, teams):    
    with_names = combined.copy()
    for suff in ['_h','_a']:
        with_names = with_names.merge(teams.rename(columns={'team':f"team{suff}",
                                                            "team_name":f'team_name{suff}'}),on = ['season',f'team{suff}'],how='left')
    unique_teams = list(set(with_names["team_name_h"]))
    name_mapping = dict(zip(unique_teams,range(len(unique_teams))))
    with_names['team_h'] = with_names.team_name_h.map(name_mapping) 
    with_names['team_a'] = with_names.team_name_a.map(name_mapping)
    with_names['days_since_fixture'] = (pd.Timestamp.utcnow() - with_names['kickoff_time']).dt.days
    return with_names, name_mapping

# %%
df, name_mapping = clean_names(combined, teams)

# %%
COLS = ['team_h','team_a','days_since_fixture','team_h_score','team_a_score']

# %%
results = df.loc[(df.finished),COLS].copy()
fixtures = df.loc[~df.finished,COLS].copy()

# %%
assert df['team_name_h'].isna().sum() == 0

# %% [markdown]
# ## Fit model - (1) Dixon-Coles like

# %% [markdown]
# We model a game with home/away score (x,y) as being
#
# $\lambda_h = exp(\mu + \gamma + \alpha_{ha} - \alpha_{ad})$
#
# $\lambda_a = exp(\gamma + \alpha_{aa} - \alpha_{hd})$
#
# $p(x,y) = \frac{exp(-\lambda_h)(\lambda_h)^x}{x!} \frac{exp(-\lambda_a)(\lambda_a)^y}{y!}$
#
# Each team has a coefficient for attacking/defending, and there is a fixed effect $\gamma$ and a home-team fixed effect $\mu$.

# %%
def neg_log_likehihood(params, df, discount, n_teams):
    '''
    Based on model above, sum the negative log likelihood, discounted by time
    '''
    mu, gamma, *alpha  = params
    alpha_score = alpha[:n_teams]
    alpha_concede = alpha[n_teams:]
    home = mu +gamma + np.take(alpha_score,df.team_h) - np.take(alpha_concede,df.team_a)
    away = gamma + np.take(alpha_score,df.team_a) - np.take(alpha_concede,df.team_h)
    exp_home = np.exp(home)
    exp_away = np.exp(away)
    neg_log_lik = exp_home - (df["team_h_score"] * home) + exp_away - (df["team_a_score"] * away)
    loss = (np.exp(-discount * df["days_since_fixture"]) * neg_log_lik).sum()
    return loss / df.shape[0]

# %%
class DixonColes():
    def __init__(self, name_mapping, discount = 0.01):
        self.name_mapping = name_mapping
        self.n_teams = len(name_mapping)
        self.discount = discount 
        self.params = [0.0 for _ in range(2 + (2*self.n_teams))]
    
    def fit(self, X): 
        '''
        Minimise negative log-likelihood
        '''
        res = scipy.optimize.minimize(
            fun=neg_log_likehihood,
            x0=self.params,
            args=(X, self.discount, self.n_teams),
        )
        mu, gamma, *alpha = res['x']
        alpha_score = alpha[:self.n_teams]
        alpha_concede = alpha[self.n_teams:]
        return mu, gamma, alpha_score, alpha_concede

# %%
mu, gamma, alpha_score, alpha_concede =  DixonColes(name_mapping).fit(results)

# %%
mu
# Out:
# 0.15180241115218393

# %%
form = pd.DataFrame(data=[name_mapping.keys(),alpha_score, alpha_concede]).T
form.columns = ['team', 'attack','defence']

# %%
form['total'] = form.attack + form.defence

# %% [markdown]
# This seams like a reasonable form ranking. I think the model is overrating Brentford a bit having never seen them before.

# %%
(form
 .iloc[list(set(fixtures.team_h))]
 .sort_values(by='total',ascending=False))
# Out:
#               team     attack     defence      total
# 8         Man City   0.630042      0.7063    1.33634
# 17         Chelsea   0.520072    0.746425     1.2665
# 4        Liverpool   0.681983    0.309575   0.991559
# 18       Brentford   0.448921    0.382609    0.83153
# 14         Man Utd   0.439913    0.249801   0.689714
# 19        West Ham   0.406499  -0.0325228   0.373977
# 13     Aston Villa   0.204812    0.116329   0.321141
# 24        Brighton  -0.125081    0.384516   0.259435
# 25         Everton   0.195888  0.00309451   0.198982
# 10         Arsenal  0.0586498    0.129113   0.187763
# 0            Spurs   0.206274   -0.134219  0.0720541
# 1        Leicester   0.298811    -0.32188 -0.0230688
# 3   Crystal Palace  0.0568498   -0.117739 -0.0608895
# 12           Leeds  0.0381668   -0.142341  -0.104174
# 9           Wolves   -0.38791    0.187608  -0.200302
# 2      Southampton   -0.18609  -0.0898566  -0.275946
# 16       Newcastle  0.0969205   -0.451075  -0.354154
# 5          Burnley  -0.371309   -0.209319  -0.580628
# 6          Watford  -0.283054   -0.299233  -0.582287
# 23         Norwich   -1.41789   -0.433065   -1.85096

# %% [markdown]
# ## Fit Model (2) - ELO

# %%
results['outcome'] =np.clip(results['team_h_score'] -results['team_a_score'],-1,1)

# %%
class Elo:
    def __init__(
        self,
        results,
        k_factor=20
    ):
        self.fixtures = results.copy().reset_index(drop=True)
        self.ratings =defaultdict(lambda: 1200)
        self.k_factor = k_factor
 
    def _record_expectation(self, i, fixture):
        self.fixtures.at[i, "elo_e"] = self.win_prob(fixture['team_h'], fixture['team_a'])
        self.fixtures.at[i, "elo"] = self.ratings[fixture['team_h']]


    def process_all_fixtures(self):
        for i, f in self.fixtures.iterrows():
            self._record_expectation(i, f)
            self._process_fixture(f)
        return self.fixtures, self.ratings

    def _process_fixture(self, fixture):
        win_prob = self.win_prob(fixture['team_h'], fixture['team_a'])
        self.ratings[fixture['team_h']] += (
            (fixture['outcome'] - win_prob) * self.k_factor
        )
        self.ratings[fixture['team_a']] += (
            (win_prob - fixture['outcome']) * self.k_factor
        )

    def win_prob(self, team_1, team_2):
        rating_1, rating_2 = self.ratings[team_1], self.ratings[team_2]
        q1 = 10.0 ** (rating_1 / 400)
        q2 = 10.0 ** (rating_2 / 400)
        return q1 / (q1 + q2)

# %%
results = results.sort_values(by='days_since_fixture',ascending=False)

# %%
elo =Elo(results)
historic_elo, elo_ratings =elo.process_all_fixtures()

# %% [markdown]
# ## Plot elo over time

# %%
inv_mapping = {v:k for k,v in name_mapping.items()}

# %%
historic_elo['name'] = historic_elo.team_h.map(inv_mapping)

# %%
historic_elo['neg_days_since_fixture'] = historic_elo['days_since_fixture'] * -1

# %%
filtered = historic_elo.loc[historic_elo.name.isin(['Chelsea', 'Man City', 'Liverpool','West Ham', 'Man Utd'])]

# %%
sns.lineplot(data=filtered, hue='name', y='elo', x='neg_days_since_fixture')
# Out:
# <AxesSubplot:xlabel='neg_days_since_fixture', ylabel='elo'>

# %%
form['elo'] =pd.Series(elo_ratings).sort_index()

# %%
form.iloc[list(set(fixtures.team_h))].sort_values(by='total',ascending=False).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col4{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col4{
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col4{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col4{
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col4{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row6_col4{
#             background-color:  #99c7e0;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row7_col4{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row8_col4{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row9_col4{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row10_col4{
#             background-color:  #61a7d2;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row11_col4{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row12_col4{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row13_col4{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row14_col4{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row15_col4{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row16_col4{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row17_col4{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row18_col4{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row19_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >attack</th>        <th class="col_heading level0 col2" >defence</th>        <th class="col_heading level0 col3" >total</th>        <th class="col_heading level0 col4" >elo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col0" class="data row0 col0" >Man City</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col1" class="data row0 col1" >0.630042</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col2" class="data row0 col2" >0.706300</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col3" class="data row0 col3" >1.336342</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row0_col4" class="data row0 col4" >1782.756270</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row1" class="row_heading level0 row1" >17</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col0" class="data row1 col0" >Chelsea</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col1" class="data row1 col1" >0.520072</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col2" class="data row1 col2" >0.746425</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col3" class="data row1 col3" >1.266497</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row1_col4" class="data row1 col4" >1492.779676</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col0" class="data row2 col0" >Liverpool</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col1" class="data row2 col1" >0.681983</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col2" class="data row2 col2" >0.309575</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col3" class="data row2 col3" >0.991559</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row2_col4" class="data row2 col4" >1746.230961</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row3" class="row_heading level0 row3" >18</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col0" class="data row3 col0" >Brentford</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col1" class="data row3 col1" >0.448921</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col2" class="data row3 col2" >0.382609</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col3" class="data row3 col3" >0.831530</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row3_col4" class="data row3 col4" >1257.780390</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row4" class="row_heading level0 row4" >14</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col0" class="data row4 col0" >Man Utd</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col1" class="data row4 col1" >0.439913</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col2" class="data row4 col2" >0.249801</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col3" class="data row4 col3" >0.689714</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row4_col4" class="data row4 col4" >1526.742034</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row5" class="row_heading level0 row5" >19</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col0" class="data row5 col0" >West Ham</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col1" class="data row5 col1" >0.406499</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col2" class="data row5 col2" >-0.032523</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col3" class="data row5 col3" >0.373977</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row5_col4" class="data row5 col4" >1293.864273</td>
#             </tr>
#             <tr>
#                         <th id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071level0_row6" class="row_heading level0 row6" >13</th>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row6_col0" class="data row6 col0" >Aston Villa</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e00390c8071row6_col1" class="data row6 col1" >0.204812</td>
#                         <td id="T_5de37ab0_2ed6_11ec_b8f6_1e003

# %% [markdown]
# ## Map form onto fixtures

# %%
CURRENT_GAMEWEEK = 7 # I should probably calculate this from fixtures

# %% [markdown]
# map on the expected scoring rates

# %%
fixtures['score'] = np.exp(mu +gamma + np.take(alpha_score,fixtures.team_h) - np.take(alpha_concede,fixtures.team_a))
fixtures['opp_score'] = np.exp(gamma + np.take(alpha_score,fixtures.team_a) - np.take(alpha_concede,fixtures.team_h))

# %%
fixtures['elo_win'] =fixtures.apply(lambda row: elo.win_prob(row['team_h'],row['team_a']),axis=1)

# %%
fixtures['team'] = fixtures['team_h'].map(inv_mapping)
fixtures['opp'] = fixtures['team_a'].map(inv_mapping)

# %% [markdown]
# We flip home and away fixtures to have all fixtures for all teams in long format

# %%
upcoming_difficulties = fixtures[['team','opp','score','elo_win','opp_score','days_since_fixture']]

# %%
flipped_difficulties = upcoming_difficulties.copy().rename(columns={'team':'opp',
                                                                    'opp':'team',
                                                                    'score':'opp_score',
                                                                    'opp_score':'score',})
flipped_difficulties['elo_win'] = 1 -flipped_difficulties['elo_win']

# %%
assert (upcoming_difficulties.groupby('team')['opp'].count() + upcoming_difficulties.groupby('opp')['team'].count()).max() == 38 - CURRENT_GAMEWEEK

# %%
combined_difficulties = upcoming_difficulties.append(flipped_difficulties)

# %%
combined_difficulties['gw'] = combined_difficulties.reset_index().sort_values(by='days_since_fixture').groupby('team').days_since_fixture.cumcount() +1 + CURRENT_GAMEWEEK

# %%
score_pivot = pd.pivot_table(data=combined_difficulties,values='score',
                             index='team',columns='gw')

# %%
defend_pivot = pd.pivot_table(data=combined_difficulties,values='opp_score',
                              index='team',columns='gw')

# %%
elo_pivot = pd.pivot_table(data=combined_difficulties,values='elo_win',
                              index='team',columns='gw')

# %% [markdown]
# Filter the data for the next n weeks

# %%
N = 5

# %%
for outcome in ['score','opp_score','elo_win']:
    print(outcome)
    pivot = pd.pivot_table(data=combined_difficulties,values=outcome,
                             index='team',columns='gw')
    n_week = pivot.iloc[:,:N].copy()
    n_week['avg'] = n_week.mean(axis=1)
    display(n_week
     .sort_values(by='avg',ascending=False) 
     .style.background_gradient(cmap='Blues'))
# Out:
# score
# <style  type="text/css" >
# #T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col0{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col1,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col2,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col5,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col3,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col4,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col3{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row0_col4{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col0,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row18_col4{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col1{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col2{
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row1_col5{
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col1{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col2,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row11_col1{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col3{
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col4,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col2{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row2_col5{
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col0,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col5{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col1{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col2{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col3{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col4{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row3_col5{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col0{
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col1,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col3{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col2{
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col3,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row17_col3{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row4_col4{
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col0,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row14_col3{
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col1{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col2,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col4,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col1,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col5{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row5_col5{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col0{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col1{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col2,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row13_col3{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col3,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col3,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col3{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col4{
#             background-color:  #82bbdb;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row6_col5{
#             background-color:  #4997c9;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col0{
#             background-color:  #97c6df;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col1{
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col4{
#             background-color:  #87bddc;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row7_col5,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col3{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col0{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col1{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col2{
#             background-color:  #68acd5;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col4,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row14_col4{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row8_col5,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col5{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col0,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row15_col0{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col1{
#             background-color:  #4695c8;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col2{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row9_col4,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row16_col4{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col0{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col2,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row15_col5{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col3{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row10_col4{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row11_col0,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row17_col1,#T_5df90ec0_2ed6_11ec_9299_1e00390c8071row18_col1{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_5df90ec0_2ed6_11ec_9299
# opp_score
# <style  type="text/css" >
# #T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col0{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col1{
#             background-color:  #4292c6;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col2,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col4,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col5,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col1,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row0_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col0{
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col0{
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col1{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col2{
#             background-color:  #68acd5;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col3{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col4{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row1_col5{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col0,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col4{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col2,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col4{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col4{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row2_col5{
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col1,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col5{
#             background-color:  #4695c8;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col2{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col4{
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row3_col5{
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col0{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col1{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col2{
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col3{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row4_col5{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col0,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col0{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col1{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col2{
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col3{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row5_col4{
#             background-color:  #87bddc;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col1{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col2{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col3{
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col4,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row18_col4{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row6_col5{
#             background-color:  #61a7d2;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col1,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col0,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row14_col1{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col2,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row19_col4{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col4{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row7_col5{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col0{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col1{
#             background-color:  #60a7d2;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col2{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row12_col1{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col4,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row19_col0{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row8_col5,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col1,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row11_col4,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row13_col2{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col1{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col2,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row13_col3{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col3{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col4,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row18_col1{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row9_col5{
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col0{
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col2{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col3,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row15_col5,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row18_col3{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row10_col5,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row16_col1,#T_5dfc6728_2ed6_11ec_8977_1e00390c8071row16_col3{
#             background-color:  #91c3de;
#             co
# elo_win
# <style  type="text/css" >
# #T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col0,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col5,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col0,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col1,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col1{
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col3{
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row0_col4{
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col1{
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col3{
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col4{
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row1_col5{
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col0{
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col2{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col4{
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row2_col5{
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col0{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col1{
#             background-color:  #2979b9;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col5{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col3{
#             background-color:  #084285;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col4{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row3_col5{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col0{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col1,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row11_col1{
#             background-color:  #87bddc;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col0{
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col4{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row4_col5,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row15_col4{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col0{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col1{
#             background-color:  #4997c9;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col3{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row5_col4{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col1{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col2{
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col3{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row6_col5,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col4{
#             background-color:  #56a0ce;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col0{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col1,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row13_col1{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col2{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col0{
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col4{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row7_col5{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col0{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col1{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col2{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row12_col2{
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col4{
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row8_col5{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col0{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col1{
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col2,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col3{
#             background-color:  #3080bd;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row12_col0{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col4{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row9_col5{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col1{
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row10_col5{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row11_col0{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row11_col2{
#             background-color:  #4292c6;
#             color:  #000000;
#         }#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row11_col3,#T_5dffadb6_2ed6_11ec_9715_1e00390c8071row15_col2,#T_5dffadb6_2ed6_1

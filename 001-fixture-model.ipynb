# %% [markdown]
# # Fixture Modelling

# %% [markdown]
# How many goals are PL teams likely to score and concede in upcoming fixtures?

# %% [markdown]
# Dixon-Coles fits team-level fixed effects to 2 a 2d Poisson distribution.
#
# See here for some more technical details http://web.math.ku.dk/~rolf/teaching/thesis/DixonColes.pdf

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from datetime import timezone
import numpy as np
import scipy.stats
import scipy.optimize
import seaborn as sns

# %%
from src.utils.elo import Elo

# %%
# !cd data/Fantasy-Premier-League && git pull # pull latest data
# Out:
# Already up to date.

# %% [markdown]
# ## Load data

# %%
SEASONS = ['2018-19' ,'2019-20','2020-21', '2021-22',]

# %%
BASE = 'data/Fantasy-Premier-League'

# %%
combined = pd.DataFrame()
for season in SEASONS:
    df = pd.read_csv(f'{BASE}/data/{season}/fixtures.csv',parse_dates=['kickoff_time'])
    df['season'] = season
    combined = df.append(combined)

# %%
teams = pd.read_csv(f'{BASE}/data/master_team_list.csv')

# %% [markdown]
# the numbers aren't consistent across seasons so we merge on names and come up with our own numbering

# %%
def clean_names(combined, teams):    
    with_names = combined.copy()
    for suff in ['_h','_a']:
        with_names = with_names.merge(teams.rename(columns={'team':f"team{suff}",
                                                            "team_name":f'team_name{suff}'}),on = ['season',f'team{suff}'],how='left')
    unique_teams = list(set(with_names["team_name_h"]))
    name_mapping = dict(zip(unique_teams,range(len(unique_teams))))
    with_names['team_h'] = with_names.team_name_h.map(name_mapping) 
    with_names['team_a'] = with_names.team_name_a.map(name_mapping)
    with_names['days_since_fixture'] = (pd.Timestamp.utcnow() - with_names['kickoff_time']).dt.days
    return with_names, name_mapping

# %%
df, name_mapping = clean_names(combined, teams)

# %%
COLS = ['team_h','team_a','days_since_fixture','team_h_score','team_a_score']

# %%
results = df.loc[(df.finished),COLS].copy()
fixtures = df.loc[~df.finished,COLS].copy()

# %%
assert df['team_name_h'].isna().sum() == 0

# %% [markdown]
# ## Fit model - (1) Dixon-Coles like

# %% [markdown]
# We model a game with home/away score (x,y) as being
#
# $\lambda_h = exp(\mu + \gamma + \alpha_{ha} - \alpha_{ad})$
#
# $\lambda_a = exp(\gamma + \alpha_{aa} - \alpha_{hd})$
#
# $p(x,y) = \frac{exp(-\lambda_h)(\lambda_h)^x}{x!} \frac{exp(-\lambda_a)(\lambda_a)^y}{y!}$
#
# Each team has a coefficient for attacking/defending, and there is a fixed effect $\gamma$ and a home-team fixed effect $\mu$.

# %%
def neg_log_likehihood(params, df, discount, n_teams):
    '''
    Based on model above, sum the negative log likelihood, discounted by time
    '''
    mu, gamma, *alpha  = params
    alpha_score = alpha[:n_teams]
    alpha_concede = alpha[n_teams:]
    home = mu +gamma + np.take(alpha_score,df.team_h) - np.take(alpha_concede,df.team_a)
    away = gamma + np.take(alpha_score,df.team_a) - np.take(alpha_concede,df.team_h)
    exp_home = np.exp(home)
    exp_away = np.exp(away)
    neg_log_lik = exp_home - (df["team_h_score"] * home) + exp_away - (df["team_a_score"] * away)
    loss = (np.exp(-discount * df["days_since_fixture"]) * neg_log_lik).sum()
    return loss / df.shape[0]

# %%
class DixonColes():
    def __init__(self, name_mapping, discount = 0.01):
        self.name_mapping = name_mapping
        self.n_teams = len(name_mapping)
        self.discount = discount 
        self.params = [0.0 for _ in range(2 + (2*self.n_teams))]
    
    def fit(self, X): 
        '''
        Minimise negative log-likelihood
        '''
        res = scipy.optimize.minimize(
            fun=neg_log_likehihood,
            x0=self.params,
            args=(X, self.discount, self.n_teams),
        )
        self.params_ = res['x']
        mu, gamma, *alpha = self.params_
        alpha_score = alpha[:self.n_teams]
        alpha_concede = alpha[self.n_teams:]
        return mu, gamma, alpha_score, alpha_concede
    
    # if needed I can implement a predict method that uses self.params_

# %%
mu, gamma, alpha_score, alpha_concede =  DixonColes(name_mapping).fit(results)

# %%
mu
# Out:
# 0.11037797759631167

# %%
form = pd.DataFrame(data=[name_mapping.keys(),alpha_score, alpha_concede]).T
form.columns = ['team', 'attack','defence']

# %%
form['total'] = form.attack + form.defence

# %% [markdown]
# This seams like a reasonable form ranking. I think the model is overrating Brentford a bit having never seen them before.

# %%
(form
 .iloc[list(set(fixtures.team_h))]
 .sort_values(by='total',ascending=False))
# Out:
#               team     attack    defence       total
# 14         Chelsea   0.544625    1.07619     1.62081
# 11        Man City   0.553565   0.786721     1.34029
# 25       Liverpool   0.835142   0.344462      1.1796
# 1         West Ham   0.331954   0.177468    0.509422
# 3   Crystal Palace   0.267186 -0.0120566    0.255129
# 22         Arsenal  0.0385618   0.179196    0.217758
# 16         Man Utd   0.250069  -0.202065   0.0480036
# 6        Leicester   0.209211  -0.217109 -0.00789845
# 8        Brentford  0.0908461   -0.14146  -0.0506139
# 23         Burnley  0.0834645  -0.137077  -0.0536127
# 2           Wolves  -0.255824   0.191829  -0.0639944
# 21           Spurs -0.0688124 -0.0255471  -0.0943595
# 4      Aston Villa  0.0886769  -0.208433   -0.119756
# 24         Watford   0.105715  -0.241864   -0.136149
# 17        Brighton  -0.325059   0.173801   -0.151259
# 20           Leeds  -0.127945 -0.0725023   -0.200448
# 18     Southampton  -0.263219  0.0454277   -0.217791
# 10       Newcastle   0.128176  -0.432066   -0.303891
# 12         Everton    -0.1379  -0.175868   -0.313768
# 19         Norwich  -0.468975  -0.419457   -0.888432

# %% [markdown]
# ## Fit Model (2) - ELO

# %%
results['outcome'] =(np.clip(results['team_h_score'] -results['team_a_score'],-1,1) + 1) / 2

# %%
results = results.sort_values(by='days_since_fixture',ascending=False)

# %%
elo =Elo(results,team_h='team_h',team_a='team_a',k_factor=35)
historic_elo, elo_ratings =elo.process_all_fixtures()

# %% [markdown]
# ## Plot elo over time

# %%
inv_mapping = {v:k for k,v in name_mapping.items()}

# %%
historic_elo['name'] = historic_elo.team_h.map(inv_mapping)

# %%
historic_elo['neg_days_since_fixture'] = historic_elo['days_since_fixture'] * -1

# %%
filtered = historic_elo.loc[historic_elo.name.isin(['Chelsea', 'Man City', 'Liverpool','West Ham', 'Man Utd'])]

# %%
sns.lineplot(data=filtered, hue='name', y='elo', x='neg_days_since_fixture')
# Out:
# <AxesSubplot:xlabel='neg_days_since_fixture', ylabel='elo'>

# %%
form['elo'] =pd.Series(elo_ratings).sort_index()

# %%
form.iloc[list(set(fixtures.team_h))].sort_values(by='total',ascending=False)
# Out:
#               team    attack   defence     total          elo
# 20         Chelsea  0.544631  1.076202  1.620833  1396.682021
# 12        Man City  0.553552  0.786737  1.340289  1446.186332
# 23       Liverpool  0.835138  0.344442  1.179579  1406.310357
# 11        West Ham  0.331974  0.177495  0.509469  1326.503712
# 7   Crystal Palace  0.267181 -0.012042  0.255139  1226.328571
# 18         Arsenal  0.038553  0.179241  0.217794  1316.329129
# 15         Man Utd  0.250032 -0.202089  0.047943  1306.331470
# 6        Leicester  0.209218 -0.217092 -0.007874  1246.948964
# 5        Brentford  0.090835 -0.141449 -0.050614  1167.639867
# 24         Burnley  0.083459 -0.137072 -0.053613  1147.294240
# 25          Wolves -0.255814  0.191826 -0.063988  1228.054346
# 16           Spurs -0.068827 -0.025533  -0.09436  1273.042420
# 0      Aston Villa  0.088696 -0.208436  -0.11974  1194.832841
# 3          Watford  0.105721 -0.241854 -0.136133  1125.412840
# 17        Brighton -0.325046  0.173828 -0.151218  1206.505772
# 9            Leeds -0.127954 -0.072491 -0.200446  1217.038701
# 10     Southampton  -0.26323  0.045436 -0.217794  1166.869989
# 8        Newcastle  0.128173 -0.432038 -0.303865  1140.622835
# 14         Everton -0.137912 -0.175848 -0.313759  1204.105563
# 4          Norwich -0.468957 -0.419464 -0.888421  1032.391055

# %% [markdown]
# ## Map form onto fixtures

# %%
CURRENT_GAMEWEEK = ((df.season == df.season.max()) & (df.finished == True)).sum() // 10

# %% [markdown]
# map on the expected scoring rates

# %%
fixtures['score'] = np.exp(mu +gamma + np.take(alpha_score,fixtures.team_h) - np.take(alpha_concede,fixtures.team_a))
fixtures['opp_score'] = np.exp(gamma + np.take(alpha_score,fixtures.team_a) - np.take(alpha_concede,fixtures.team_h))

# %%
fixtures['elo_win'] =fixtures.apply(lambda row: elo.win_prob(row['team_h'],row['team_a']),axis=1)

# %%
fixtures['team'] = fixtures['team_h'].map(inv_mapping)
fixtures['opp'] = fixtures['team_a'].map(inv_mapping)

# %% [markdown]
# We flip home and away fixtures to have all fixtures for all teams in long format

# %%
upcoming_difficulties = fixtures[['team','opp','score','elo_win','opp_score','days_since_fixture']]

# %%
flipped_difficulties = upcoming_difficulties.copy().rename(columns={'team':'opp',
                                                                    'opp':'team',
                                                                    'score':'opp_score',
                                                                    'opp_score':'score',})
flipped_difficulties['elo_win'] = 1 -flipped_difficulties['elo_win']

# %%
assert (upcoming_difficulties.groupby('team')['opp'].count() + upcoming_difficulties.groupby('opp')['team'].count()).max() == 38 - CURRENT_GAMEWEEK

# %%
combined_difficulties = upcoming_difficulties.append(flipped_difficulties).reset_index().sort_values(by='days_since_fixture',ascending=False)

# %%
combined_difficulties['gw'] = combined_difficulties.groupby('team').days_since_fixture.cumcount() +1 + CURRENT_GAMEWEEK

# %%
score_pivot = pd.pivot_table(data=combined_difficulties,values='score',
                             index='team',columns='gw')

# %%
defend_pivot = pd.pivot_table(data=combined_difficulties,values='opp_score',
                              index='team',columns='gw')

# %%
elo_pivot = pd.pivot_table(data=combined_difficulties,values='elo_win',
                              index='team',columns='gw')

# %% [markdown]
# Filter the data for the next n weeks

# %%
N = 5

# %%
for outcome in ['score','opp_score','elo_win']:
    print(outcome)
    pivot = pd.pivot_table(data=combined_difficulties,values=outcome,
                             index='team',columns='gw')
    n_week = pivot.iloc[:,:N].copy()
    n_week['avg'] = n_week.mean(axis=1)
    sort_dir = outcome == 'opp_score'
    display(n_week
     .sort_values(by='avg',ascending=sort_dir) 
     .style.background_gradient(cmap='Blues'))
# Out:
# score
# <style type="text/css">
# #T_b4eb6_row0_col0, #T_b4eb6_row0_col1, #T_b4eb6_row0_col3, #T_b4eb6_row0_col4, #T_b4eb6_row0_col5, #T_b4eb6_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b4eb6_row0_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col4, #T_b4eb6_row7_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b4eb6_row1_col5, #T_b4eb6_row3_col3, #T_b4eb6_row4_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b4eb6_row2_col0, #T_b4eb6_row3_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_b4eb6_row2_col1 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_b4eb6_row2_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_b4eb6_row2_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b4eb6_row2_col5 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_b4eb6_row3_col0, #T_b4eb6_row6_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_b4eb6_row3_col1, #T_b4eb6_row5_col4 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b4eb6_row3_col4, #T_b4eb6_row5_col1, #T_b4eb6_row5_col5 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b4eb6_row3_col5 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_b4eb6_row4_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_b4eb6_row4_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b4eb6_row4_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b4eb6_row4_col4 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_b4eb6_row4_col5 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_b4eb6_row5_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_b4eb6_row5_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_b4eb6_row5_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b4eb6_row6_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b4eb6_row6_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_b4eb6_row6_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b4eb6_row6_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b4eb6_row6_col5, #T_b4eb6_row17_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_b4eb6_row7_col0, #T_b4eb6_row12_col2, #T_b4eb6_row13_col1, #T_b4eb6_row17_col4, #T_b4eb6_row19_col3, #T_b4eb6_row19_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b4eb6_row7_col1, #T_b4eb6_row10_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_b4eb6_row7_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_b4eb6_row7_col4 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_b4eb6_row7_col5, #T_b4eb6_row16_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b4eb6_row8_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_b4eb6_row8_col1, #T_b4eb6_row15_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_b4eb6_row8_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_b4eb6_row8_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_b4eb6_row8_col4, #T_b4eb6_row18_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_b4eb6_row8_col5, #T_b4eb6_row9_col5 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_b4eb6_row9_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_b4eb6_row9_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b4eb6_row9_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_b4eb6_row9_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b4eb6_row9_col4, #T_b4eb6_row13_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b4eb6_row10_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b4eb6_row10_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_b4eb6_row10_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b4eb6_row10_col4, #T_b4eb6_row12_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_b4eb6_row10_col5 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b4eb6_row11_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_b4eb6_row11_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b4eb6_row11_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_b4eb6_row11_col3, #T_b4eb6_row17_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_b4eb6_row11_col4 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_b4eb6_row11_col5, #T_b4eb6_row14_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_b4eb6_row12_col0, #T_b4eb6_row15_col4, #T_b4eb6_row18_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_b4eb6_row12_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_b4eb6_row12_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_b4eb6_row12_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b4eb6_row13_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_b4eb6_row13_col2, #T_b4eb6_row15_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b4eb6_row13_col4 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_b4eb6_row13_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b4eb6_row14_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b4eb6_row14_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_b4eb6_row14_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b4eb6_row14_col4 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_b4eb6_row14_col5, #T_b4eb6_row19_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_b4eb6_row15_col1, #T_b4eb6_row19_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_b4eb6_row15_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b4eb6_row15_col3, #T_b4eb6_row16_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_b4eb6_row16_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b4eb6_row16_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b4eb6_row16_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b4eb6_row16_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_b4eb6_row17_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_b4eb6_row17_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_b4eb6_row17_col5, #T_b4eb6_row18_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b4eb6_row18_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_b4eb6_row18_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b4eb6_row18_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_b4eb6_row19_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_b4eb6_row19_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# </style>
# <table id="T_b4eb6_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gw</th>
#       <th class="col_heading level0 col0" >13</th>
#       <th class="col_heading level0 col1" >14</th>
#       <th class="col_heading level0 col2" >15</th>
#       <th class="col_heading level0 col3" >16</th>
#       <th class="col_heading level0 col4" >17</th>
#       <th class="col_heading level0 col5" >avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4eb6_level0_row0" class="row_heading level0 row0" >Liverpool</th>
#       <td id="T_b4eb6_row0_col0" class="data row0 col0" >2.831445</td>
#       <td id="T_b4eb6_row0_col1" class="data row0 col1" >3.163541</td>
#       <td id="T_b4eb6_row0_col2" class="data row0 col2" >2.190256</td>
#       <td id="T_b4eb6_row0_col3" class="data row0 col3" >3.649752</td>
#       <td id="T_b4eb6_row0_col4" class="data row0 col4" >4.564283</td>
#       <td id="T_b4eb6_row0_col5" class="data row0 col5" >3.279855</t
# opp_score
# <style type="text/css">
# #T_8e41b_row0_col0, #T_8e41b_row0_col1, #T_8e41b_row0_col2, #T_8e41b_row0_col3, #T_8e41b_row0_col4, #T_8e41b_row0_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8e41b_row1_col0, #T_8e41b_row3_col4, #T_8e41b_row12_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8e41b_row1_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_8e41b_row1_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8e41b_row1_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_8e41b_row1_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_8e41b_row1_col5 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_8e41b_row2_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_8e41b_row2_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_8e41b_row2_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8e41b_row2_col3, #T_8e41b_row4_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_8e41b_row2_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_8e41b_row2_col5, #T_8e41b_row3_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_8e41b_row3_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8e41b_row3_col1, #T_8e41b_row6_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_8e41b_row3_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_8e41b_row3_col5 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_8e41b_row4_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_8e41b_row4_col1, #T_8e41b_row9_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_8e41b_row4_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_8e41b_row4_col4, #T_8e41b_row11_col4 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8e41b_row4_col5, #T_8e41b_row12_col1, #T_8e41b_row13_col4 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_8e41b_row5_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_8e41b_row5_col1, #T_8e41b_row10_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_8e41b_row5_col2, #T_8e41b_row17_col4 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_8e41b_row5_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8e41b_row5_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_8e41b_row5_col5 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_8e41b_row6_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_8e41b_row6_col1, #T_8e41b_row6_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8e41b_row6_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8e41b_row6_col3, #T_8e41b_row8_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_8e41b_row7_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_8e41b_row7_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_8e41b_row7_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_8e41b_row7_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_8e41b_row7_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_8e41b_row7_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_8e41b_row8_col0, #T_8e41b_row18_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_8e41b_row8_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8e41b_row8_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_8e41b_row8_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_8e41b_row8_col5 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_8e41b_row9_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_8e41b_row9_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_8e41b_row9_col3, #T_8e41b_row16_col4 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_8e41b_row9_col4 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_8e41b_row9_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_8e41b_row10_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_8e41b_row10_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_8e41b_row10_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_8e41b_row10_col4 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_8e41b_row10_col5 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_8e41b_row11_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_8e41b_row11_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8e41b_row11_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_8e41b_row11_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_8e41b_row11_col5 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_8e41b_row12_col0, #T_8e41b_row16_col2, #T_8e41b_row17_col1, #T_8e41b_row18_col3, #T_8e41b_row19_col4, #T_8e41b_row19_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8e41b_row12_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_8e41b_row12_col4 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_8e41b_row12_col5 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_8e41b_row13_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_8e41b_row13_col1, #T_8e41b_row15_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_8e41b_row13_col2, #T_8e41b_row19_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_8e41b_row13_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_8e41b_row13_col5 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_8e41b_row14_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_8e41b_row14_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_8e41b_row14_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_8e41b_row14_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_8e41b_row14_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_8e41b_row14_col5 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_8e41b_row15_col1, #T_8e41b_row16_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_8e41b_row15_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_8e41b_row15_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_8e41b_row15_col4 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_8e41b_row15_col5, #T_8e41b_row18_col1 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_8e41b_row16_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_8e41b_row16_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_8e41b_row16_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_8e41b_row17_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_8e41b_row17_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_8e41b_row17_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_8e41b_row17_col5, #T_8e41b_row18_col5 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_8e41b_row18_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_8e41b_row18_col4 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_8e41b_row19_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_8e41b_row19_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_8e41b_row19_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e41b_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gw</th>
#       <th class="col_heading level0 col0" >13</th>
#       <th class="col_heading level0 col1" >14</th>
#       <th class="col_heading level0 col2" >15</th>
#       <th class="col_heading level0 col3" >16</th>
#       <th class="col_heading level0 col4" >17</th>
#       <th class="col_heading level0 col5" >avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e41b_level0_row0" class="row_heading level0 row0" >Chelsea</th>
#       <td id="T_8e41b_row0_col0" class="data row0 col0" >0.503857</td>
#       <td id="T_8e41b_row0_col1" class="data row0 col1" >0.487046</td>
#       <td id="T_8e41b_row0_col2"
# elo_win
# <style type="text/css">
# #T_a1e62_row0_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_a1e62_row0_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_a1e62_row0_col2, #T_a1e62_row0_col5, #T_a1e62_row1_col0, #T_a1e62_row1_col4, #T_a1e62_row2_col1, #T_a1e62_row5_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a1e62_row0_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_a1e62_row0_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_a1e62_row1_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_a1e62_row1_col2 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_a1e62_row1_col3, #T_a1e62_row3_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_a1e62_row1_col5 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_a1e62_row2_col0, #T_a1e62_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_a1e62_row2_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_a1e62_row2_col3, #T_a1e62_row7_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_a1e62_row2_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a1e62_row2_col5 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_a1e62_row3_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_a1e62_row3_col1, #T_a1e62_row6_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_a1e62_row3_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_a1e62_row3_col4 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_a1e62_row3_col5, #T_a1e62_row7_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_a1e62_row4_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_a1e62_row4_col1, #T_a1e62_row7_col4, #T_a1e62_row8_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_a1e62_row4_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_a1e62_row4_col4, #T_a1e62_row5_col1, #T_a1e62_row12_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_a1e62_row4_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_a1e62_row5_col0, #T_a1e62_row16_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_a1e62_row5_col2, #T_a1e62_row5_col5 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_a1e62_row5_col4 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_a1e62_row6_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_a1e62_row6_col1, #T_a1e62_row9_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_a1e62_row6_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_a1e62_row6_col4 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_a1e62_row6_col5 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_a1e62_row7_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_a1e62_row7_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_a1e62_row7_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_a1e62_row8_col0, #T_a1e62_row10_col2 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_a1e62_row8_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_a1e62_row8_col3, #T_a1e62_row9_col4, #T_a1e62_row14_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_a1e62_row8_col4 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_a1e62_row8_col5 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_a1e62_row9_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_a1e62_row9_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_a1e62_row9_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_a1e62_row9_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_a1e62_row10_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_a1e62_row10_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a1e62_row10_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_a1e62_row10_col4, #T_a1e62_row16_col3, #T_a1e62_row18_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_a1e62_row10_col5 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_a1e62_row11_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_a1e62_row11_col1, #T_a1e62_row15_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_a1e62_row11_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_a1e62_row11_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_a1e62_row11_col4 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_a1e62_row11_col5 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_a1e62_row12_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_a1e62_row12_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_a1e62_row12_col3, #T_a1e62_row14_col3 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_a1e62_row12_col4 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_a1e62_row12_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_a1e62_row13_col0, #T_a1e62_row17_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_a1e62_row13_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a1e62_row13_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_a1e62_row13_col3, #T_a1e62_row19_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_a1e62_row13_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_a1e62_row13_col5, #T_a1e62_row14_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_a1e62_row14_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_a1e62_row14_col1, #T_a1e62_row17_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_a1e62_row14_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_a1e62_row15_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_a1e62_row15_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_a1e62_row15_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_a1e62_row15_col4, #T_a1e62_row17_col0, #T_a1e62_row18_col1, #T_a1e62_row18_col2, #T_a1e62_row19_col3, #T_a1e62_row19_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a1e62_row15_col5 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_a1e62_row16_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_a1e62_row16_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_a1e62_row16_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_a1e62_row16_col5 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_a1e62_row17_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_a1e62_row17_col4 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_a1e62_row17_col5 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_a1e62_row18_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_a1e62_row18_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_a1e62_row18_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_a1e62_row19_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_a1e62_row19_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_a1e62_row19_col4 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# </style>
# <table id="T_a1e62_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gw</th>
#       <th class="col_heading level0 col0" >13</th>
#       <th class="col_heading level0 col1" >14</th>
#       <th class="col_heading level0 col2" >15</th>
#       <th class="col_heading level0 col3" >16</th>
#       <th class="col_heading level0 col4" >17</th>
#       <th class="col_heading level0 col5" >avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1e62_level0_row0" class="row_heading level0 row0" >Man City</th>
#       <td id="T_a1e62_row0_col0" class="data row0 col0" >0.665733</td>
#       <td id="T_a1e62_row0_col1" class="data row0 col1" >0.809522</td>
#       <td id="T_a1e62_row0_col2" class="data row0 col2" >0.863718</td>
#       <td id="T_a1e62_row0_col3" class="data row0 col3" >0.778280</td>
#       <td id="T_a1e62_row0_col4" class="

# %%
combined_difficulties.pivot(index='team',columns='gw',values='opp').iloc[:,:N]
# Out:
# gw                          13              14              15  \
# team
# Arsenal              Newcastle         Man Utd         Everton
# Aston Villa     Crystal Palace        Man City       Leicester
# Brentford              Everton           Spurs           Leeds
# Brighton                 Leeds        West Ham     Southampton
# Burnley                  Spurs          Wolves       Newcastle
# Chelsea                Man Utd         Watford        West Ham
# Crystal Palace     Aston Villa           Leeds         Man Utd
# Everton              Brentford       Liverpool         Arsenal
# Leeds                 Brighton  Crystal Palace       Brentford
# Leicester              Watford     Southampton     Aston Villa
# Liverpool          Southampton         Everton          Wolves
# Man City              West Ham     Aston Villa         Watford
# Man Utd                Chelsea         Arsenal  Crystal Palace
# Newcastle              Arsenal         Norwich         Burnley
# Norwich                 Wolves       Newcastle           Spurs
# Southampton          Liverpool       Leicester        Brighton
# Spurs                  Burnley       Brentford         Norwich
# Watford              Leicester         Chelsea        Man City
# West Ham              Man City        Brighton         Chelsea
# Wolves                 Norwich         Burnley       Liverpool
#
# gw                          16              17
# team
# Arsenal            Southampton        West Ham
# Aston Villa          Liverpool         Norwich
# Brentford              Watford         Man Utd
# Brighton                 Spurs          Wolves
# Burnley               West Ham         Watford
# Chelsea                  Leeds         Everton
# Crystal Palace         Everton     Southampton
# Everton         Crystal Palace         Chelsea
# Leeds                  Chelsea        Man City
# Leicester            Newcastle           Spurs
# Liverpool          Aston Villa       Newcastle
# Man City                Wolves           Leeds
# Man Utd                Norwich       Brentford
# Newcastle            Leicester       Liverpool
# Norwich                Man Utd     Aston Villa
# Southampton            Arsenal  Crystal Palace
# Spurs                 Brighton       Leicester
# Watford              Brentford         Burnley
# West Ham               Burnley         Arsenal
# Wolves                Man City        Brighton

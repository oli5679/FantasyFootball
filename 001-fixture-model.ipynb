# %% [markdown]
# # Fixture Modelling

# %% [markdown]
# How many goals are PL teams likely to score and concede in upcoming fixtures?

# %% [markdown]
# Dixon-Coles fits team-level fixed effects to 2 a 2d Poisson distribution.
#
# See here for some more technical details http://web.math.ku.dk/~rolf/teaching/thesis/DixonColes.pdf

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from datetime import timezone
import numpy as np
import scipy.stats
import scipy.optimize
import seaborn as sns

# %%
from src.utils.elo import Elo

# %%
# !cd data/Fantasy-Premier-League && git pull # pull latest data
# Out:
# Already up to date.

# %% [markdown]
# ## Load data

# %%
SEASONS = ['2018-19' ,'2019-20','2020-21', '2021-22',]

# %%
BASE = 'data/Fantasy-Premier-League'

# %%
combined = pd.DataFrame()
for season in SEASONS:
    df = pd.read_csv(f'{BASE}/data/{season}/fixtures.csv',parse_dates=['kickoff_time'])
    df['season'] = season
    combined = df.append(combined)

# %%
teams = pd.read_csv(f'{BASE}/data/master_team_list.csv')

# %% [markdown]
# the numbers aren't consistent across seasons so we merge on names and come up with our own numbering

# %%
def clean_names(combined, teams):    
    with_names = combined.copy()
    for suff in ['_h','_a']:
        with_names = with_names.merge(teams.rename(columns={'team':f"team{suff}",
                                                            "team_name":f'team_name{suff}'}),on = ['season',f'team{suff}'],how='left')
    unique_teams = list(set(with_names["team_name_h"]))
    name_mapping = dict(zip(unique_teams,range(len(unique_teams))))
    with_names['team_h'] = with_names.team_name_h.map(name_mapping) 
    with_names['team_a'] = with_names.team_name_a.map(name_mapping)
    with_names['days_since_fixture'] = (pd.Timestamp.utcnow() - with_names['kickoff_time']).dt.days
    return with_names, name_mapping

# %%
df, name_mapping = clean_names(combined, teams)

# %%
COLS = ['team_h','team_a','days_since_fixture','team_h_score','team_a_score']

# %%
results = df.loc[(df.finished),COLS].copy()
fixtures = df.loc[~df.finished,COLS].copy()

# %%
assert df['team_name_h'].isna().sum() == 0

# %% [markdown]
# ## Fit model - (1) Dixon-Coles like

# %% [markdown]
# We model a game with home/away score (x,y) as being
#
# $\lambda_h = exp(\mu + \gamma + \alpha_{ha} - \alpha_{ad})$
#
# $\lambda_a = exp(\gamma + \alpha_{aa} - \alpha_{hd})$
#
# $p(x,y) = \frac{exp(-\lambda_h)(\lambda_h)^x}{x!} \frac{exp(-\lambda_a)(\lambda_a)^y}{y!}$
#
# Each team has a coefficient for attacking/defending, and there is a fixed effect $\gamma$ and a home-team fixed effect $\mu$.

# %%
def neg_log_likehihood(params, df, discount, n_teams):
    '''
    Based on model above, sum the negative log likelihood, discounted by time
    '''
    mu, gamma, *alpha  = params
    alpha_score = alpha[:n_teams]
    alpha_concede = alpha[n_teams:]
    home = mu +gamma + np.take(alpha_score,df.team_h) - np.take(alpha_concede,df.team_a)
    away = gamma + np.take(alpha_score,df.team_a) - np.take(alpha_concede,df.team_h)
    exp_home = np.exp(home)
    exp_away = np.exp(away)
    neg_log_lik = exp_home - (df["team_h_score"] * home) + exp_away - (df["team_a_score"] * away)
    loss = (np.exp(-discount * df["days_since_fixture"]) * neg_log_lik).sum()
    return loss / df.shape[0]

# %%
class DixonColes():
    def __init__(self, name_mapping, discount = 0.01):
        self.name_mapping = name_mapping
        self.n_teams = len(name_mapping)
        self.discount = discount 
        self.params = [0.0 for _ in range(2 + (2*self.n_teams))]
    
    def fit(self, X): 
        '''
        Minimise negative log-likelihood
        '''
        res = scipy.optimize.minimize(
            fun=neg_log_likehihood,
            x0=self.params,
            args=(X, self.discount, self.n_teams),
        )
        self.params_ = res['x']
        mu, gamma, *alpha = self.params_
        alpha_score = alpha[:self.n_teams]
        alpha_concede = alpha[self.n_teams:]
        return mu, gamma, alpha_score, alpha_concede
    
    # if needed I can implement a predict method that uses self.params_

# %%
mu, gamma, alpha_score, alpha_concede =  DixonColes(name_mapping).fit(results)

# %%
mu

# %%
form = pd.DataFrame(data=[name_mapping.keys(),alpha_score, alpha_concede]).T
form.columns = ['team', 'attack','defence']

# %%
form['total'] = form.attack + form.defence

# %% [markdown]
# This seams like a reasonable form ranking. I think the model is overrating Brentford a bit having never seen them before.

# %%
(form
 .iloc[list(set(fixtures.team_h))]
 .sort_values(by='total',ascending=False))

# %% [markdown]
# ## Fit Model (2) - ELO

# %%
results['outcome'] =(np.clip(results['team_h_score'] -results['team_a_score'],-1,1) + 1) / 2

# %%
results = results.sort_values(by='days_since_fixture',ascending=False)

# %%
elo =Elo(results,team_h='team_h',team_a='team_a',k_factor=35)
historic_elo, elo_ratings =elo.process_all_fixtures()

# %% [markdown]
# ## Plot elo over time

# %%
inv_mapping = {v:k for k,v in name_mapping.items()}

# %%
historic_elo['name'] = historic_elo.team_h.map(inv_mapping)

# %%
historic_elo['neg_days_since_fixture'] = historic_elo['days_since_fixture'] * -1

# %%
filtered = historic_elo.loc[historic_elo.name.isin(['Chelsea', 'Man City', 'Liverpool','West Ham', 'Man Utd'])]

# %%
sns.lineplot(data=filtered, hue='name', y='elo', x='neg_days_since_fixture')
# Out:
# <AxesSubplot:xlabel='neg_days_since_fixture', ylabel='elo'>

# %%
form['elo'] =pd.Series(elo_ratings).sort_index()

# %%
form.iloc[list(set(fixtures.team_h))].sort_values(by='total',ascending=False)
# Out:
#               team     attack    defence       total          elo
# 6          Chelsea   0.544627    1.07619     1.62082  1396.682021
# 5         Man City   0.553563   0.786727     1.34029  1446.186332
# 13       Liverpool   0.835141   0.344465     1.17961  1406.310357
# 22        West Ham   0.331956   0.177473     0.50943  1326.503712
# 23  Crystal Palace   0.267185 -0.0120517    0.255133  1226.328571
# 20         Arsenal  0.0385612   0.179202    0.217763  1316.329129
# 3          Man Utd   0.250066  -0.202063   0.0480028  1306.331470
# 10       Leicester   0.209212  -0.217104 -0.00789207  1246.948964
# 21       Brentford   0.090845  -0.141455  -0.0506101  1167.639867
# 25         Burnley  0.0834639  -0.137073  -0.0536089  1147.294240
# 16          Wolves  -0.255823   0.191833  -0.0639899  1228.054346
# 1            Spurs -0.0688131 -0.0255426  -0.0943557  1273.042420
# 0      Aston Villa   0.088678  -0.208428    -0.11975  1194.832841
# 19         Watford   0.105715  -0.241859   -0.136144  1125.412840
# 24        Brighton  -0.325059   0.173806   -0.151252  1206.505772
# 15           Leeds  -0.127945 -0.0724978   -0.200443  1217.038701
# 14     Southampton  -0.263219  0.0454317   -0.217788  1166.869989
# 9        Newcastle   0.128175  -0.432061   -0.303885  1140.622835
# 11         Everton    -0.1379  -0.175861   -0.313762  1204.105563
# 18         Norwich  -0.468977  -0.419453   -0.888431  1032.391055

# %% [markdown]
# ## Map form onto fixtures

# %%
CURRENT_GAMEWEEK = ((df.season == df.season.max()) & (df.finished == True)).sum() // 10

# %% [markdown]
# map on the expected scoring rates

# %%
fixtures['score'] = np.exp(mu +gamma + np.take(alpha_score,fixtures.team_h) - np.take(alpha_concede,fixtures.team_a))
fixtures['opp_score'] = np.exp(gamma + np.take(alpha_score,fixtures.team_a) - np.take(alpha_concede,fixtures.team_h))

# %%
fixtures['elo_win'] =fixtures.apply(lambda row: elo.win_prob(row['team_h'],row['team_a']),axis=1)

# %%
fixtures['team'] = fixtures['team_h'].map(inv_mapping)
fixtures['opp'] = fixtures['team_a'].map(inv_mapping)

# %% [markdown]
# We flip home and away fixtures to have all fixtures for all teams in long format

# %%
upcoming_difficulties = fixtures[['team','opp','score','elo_win','opp_score','days_since_fixture']]

# %%
flipped_difficulties = upcoming_difficulties.copy().rename(columns={'team':'opp',
                                                                    'opp':'team',
                                                                    'score':'opp_score',
                                                                    'opp_score':'score',})
flipped_difficulties['elo_win'] = 1 -flipped_difficulties['elo_win']

# %%
assert (upcoming_difficulties.groupby('team')['opp'].count() + upcoming_difficulties.groupby('opp')['team'].count()).max() == 38 - CURRENT_GAMEWEEK

# %%
combined_difficulties = upcoming_difficulties.append(flipped_difficulties).reset_index().sort_values(by='days_since_fixture',ascending=False)

# %%
combined_difficulties['gw'] = combined_difficulties.groupby('team').days_since_fixture.cumcount() +1 + CURRENT_GAMEWEEK

# %%
score_pivot = pd.pivot_table(data=combined_difficulties,values='score',
                             index='team',columns='gw')

# %%
defend_pivot = pd.pivot_table(data=combined_difficulties,values='opp_score',
                              index='team',columns='gw')

# %%
elo_pivot = pd.pivot_table(data=combined_difficulties,values='elo_win',
                              index='team',columns='gw')

# %% [markdown]
# Filter the data for the next n weeks

# %%
N = 5

# %%
for outcome in ['score','opp_score','elo_win']:
    print(outcome)
    pivot = pd.pivot_table(data=combined_difficulties,values=outcome,
                             index='team',columns='gw')
    n_week = pivot.iloc[:,:N].copy()
    n_week['avg'] = n_week.mean(axis=1)
    sort_dir = outcome == 'opp_score'
    display(n_week
     .sort_values(by='avg',ascending=sort_dir) 
     .style.background_gradient(cmap='Blues'))
# Out:
# score
# <style  type="text/css" >
# #T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col0,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col3,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col5,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow0_col2{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col0{
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col1{
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col2{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col3{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col2{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow1_col5,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col3,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col2{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col0,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col2{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col1{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col3{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col4{
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow2_col5{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col0,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col1{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col4{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col5{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow3_col5{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col0{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col1{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col3{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col4{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow4_col5{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col0{
#             background-color:  #69add5;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col2{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow5_col3{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col0{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col2{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col3{
#             background-color:  #99c7e0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col4{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow6_col5,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow17_col0{
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col0,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow12_col2,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow13_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow17_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow19_col3,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow19_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col1{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col3{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col4{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow7_col5,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow16_col1{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col0{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col1,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow15_col0{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col2{
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col3{
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow18_col3{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow8_col5,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col5{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col0{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col1{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col2{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col3{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow9_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow13_col3{
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col0{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col2{
#             background-color:  #4191c6;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col3{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col4,#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow12_col4{
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow10_col5{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674_be2d5e5c09bbrow11_col0{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_5bd3ab36_4d13_11ec_b674
# opp_score
# <style  type="text/css" >
# #T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col0,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col2,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col3,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col4,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow0_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col0,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col4,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow12_col2{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col1{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col2{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col3{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col4{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow1_col5{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col1{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col2{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col3,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col2{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col4{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow2_col5,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col3{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col0{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col5{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col2{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow3_col5{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col0{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col1{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col3{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col4,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow11_col4{
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow4_col5,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow12_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow13_col4{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col0{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col1{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col2,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow17_col4{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col3{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col4{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow5_col5{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col0{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col1,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col4{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col2{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow6_col3,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col4{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col0{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col1{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col2{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col3{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col4{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow7_col5{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col0,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow18_col2{
#             background-color:  #4e9acb;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col1{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col2{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col3{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow8_col5{
#             background-color:  #87bddc;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col0{
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col3,#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow16_col4{
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col4{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow9_col5{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col0{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col2{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col3{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col4{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow10_col5{
#             background-color:  #65aad4;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow11_col0{
#             background-color:  #79b5d9;
#             color:  #000000;
#         }#T_5bd9b9fe_4d13_11ec_a52b_be2d5e5c09bbrow11_col1{
#             backg
# elo_win
# <style  type="text/css" >
# #T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col0{
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col1{
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col2,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col5,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col0,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col4,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col3{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow0_col4{
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col1{
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col2{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col3,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col2{
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow1_col5{
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col0,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col2{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col2{
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col3,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col3{
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col4{
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow2_col5{
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col0{
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col3{
#             background-color:  #2777b8;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col3{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col4{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow3_col5,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col1{
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col0{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col4,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col1{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col3{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col4,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow12_col1{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow4_col5{
#             background-color:  #3080bd;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col0,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow16_col2{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col2,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col5{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow5_col4{
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col0{
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col1{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col2{
#             background-color:  #4997c9;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col4{
#             background-color:  #82bbdb;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow6_col5{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col0{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col2{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow7_col5{
#             background-color:  #61a7d2;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col0,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col2{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col2{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col3,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col4,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow14_col4{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col4{
#             background-color:  #4090c5;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow8_col5{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col0{
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col2{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col3{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow9_col5{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col0{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col1{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col3{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col4,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow16_col3,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow18_col4{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow10_col5{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow11_col0{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow11_col1,#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow15_col3{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow11_col2{
#             background-color:  #92c4de;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow11_col3{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_5bdd25b4_4d13_11ec_a22a_be2d5e5c09bbrow11_co

# %%
combined_difficulties.pivot(index='team',columns='gw',values='opp').iloc[:,:N]
# Out:
# gw                          13              14              15  \
# team
# Arsenal              Newcastle         Man Utd         Everton
# Aston Villa     Crystal Palace        Man City       Leicester
# Brentford              Everton           Spurs           Leeds
# Brighton                 Leeds        West Ham     Southampton
# Burnley                  Spurs          Wolves       Newcastle
# Chelsea                Man Utd         Watford        West Ham
# Crystal Palace     Aston Villa           Leeds         Man Utd
# Everton              Brentford       Liverpool         Arsenal
# Leeds                 Brighton  Crystal Palace       Brentford
# Leicester              Watford     Southampton     Aston Villa
# Liverpool          Southampton         Everton          Wolves
# Man City              West Ham     Aston Villa         Watford
# Man Utd                Chelsea         Arsenal  Crystal Palace
# Newcastle              Arsenal         Norwich         Burnley
# Norwich                 Wolves       Newcastle           Spurs
# Southampton          Liverpool       Leicester        Brighton
# Spurs                  Burnley       Brentford         Norwich
# Watford              Leicester         Chelsea        Man City
# West Ham              Man City        Brighton         Chelsea
# Wolves                 Norwich         Burnley       Liverpool
#
# gw                          16              17
# team
# Arsenal            Southampton        West Ham
# Aston Villa          Liverpool         Norwich
# Brentford              Watford         Man Utd
# Brighton                 Spurs          Wolves
# Burnley               West Ham         Watford
# Chelsea                  Leeds         Everton
# Crystal Palace         Everton     Southampton
# Everton         Crystal Palace         Chelsea
# Leeds                  Chelsea        Man City
# Leicester            Newcastle           Spurs
# Liverpool          Aston Villa       Newcastle
# Man City                Wolves           Leeds
# Man Utd                Norwich       Brentford
# Newcastle            Leicester       Liverpool
# Norwich                Man Utd     Aston Villa
# Southampton            Arsenal  Crystal Palace
# Spurs                 Brighton       Leicester
# Watford              Brentford         Burnley
# West Ham               Burnley         Arsenal
# Wolves                Man City        Brighton
